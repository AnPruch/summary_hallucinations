# %%
data = {'podcast': {'negation_insertion_removal': 62, 'entity_modification': 282, 'hallucinated_fact_insertion': 117, 'antonym_swap': 211},
'billsum': {'negation_insertion_removal': 57, 'entity_modification': 388, 'hallucinated_fact_insertion': 79, 'antonym_swap': 205},
'samsum': {'negation_insertion_removal': 71, 'entity_modification': 329, 'hallucinated_fact_insertion': 76, 'antonym_swap': 163},
'news': {'negation_insertion_removal': 85, 'entity_modification': 411, 'hallucinated_fact_insertion': 51, 'antonym_swap': 198},
'sales_call': {'negation_insertion_removal': 104, 'entity_modification': 267, 'hallucinated_fact_insertion': 167, 'antonym_swap': 117},
'sales_email': {'negation_insertion_removal': 64, 'entity_modification': 342, 'hallucinated_fact_insertion': 152, 'antonym_swap': 197},
'shakespeare': {'antonym_swap': 282, 'hallucinated_fact_insertion': 102, 'negation_insertion_removal': 91, 'entity_modification': 374},
'scitldr': {'negation_insertion_removal': 51, 'entity_modification': 189, 'hallucinated_fact_insertion': 33, 'antonym_swap': 194},
'qmsumm': {'negation_insertion_removal': 103, 'entity_modification': 169, 'hallucinated_fact_insertion': 51, 'antonym_swap': 129},
'ectsum': {'negation_insertion_removal': 44, 'entity_modification': 367, 'hallucinated_fact_insertion': 60, 'antonym_swap': 241}}

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
name = 'podcast'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'podcast')

# %%
name = 'billsum'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'billsum')

# %%
name = 'samsum'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'samsum')

# %%
name = 'news'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'news')

# %%
name = 'sales_call'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'sales_call')

# %%
name = 'sales_email'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'sales_email')

# %%
name = 'shakespeare'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'shakespeare')

# %%
name = 'scitldr'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'scitldr')

# %%
name = 'qmsumm'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'qmsumm')

# %%
name = 'ectsum'
d = data[name]
plt.pie(d.values(), labels=d.keys(), autopct='%1.2f%%')
plt.title(name)
# Out:
# Text(0.5, 1.0, 'ectsum')
